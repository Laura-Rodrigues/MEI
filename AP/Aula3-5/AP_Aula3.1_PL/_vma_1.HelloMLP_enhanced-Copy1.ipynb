# %% [markdown]
# ## **MLP para classificação binária**
# **Dataset Ionosphere**
# - Dataset de texto com previsão da existência de uma estrutura na atomosfera com dados de um radar
# - Classificação "good" significa evidência de estrutura na ionosfera e "bad" o contrário
# - 34 atributos contínuos (numéricos) e o 35º é a classificação de "good"/"bad" com "g"/"b"
# - 350 instâncias

# %% [markdown]
# ## Pipeline de um processo de Deep Learning implementado em PyTorch:
#
#     1. Preparar os Dados
#     2. Definir o Modelo
#     3. Treinar o Modelo
#     4. Avaliar o Modelo
#     5. Usar o Modelo

# %% [markdown]
# ## Melhoramento do Modelo

# %%
# Confirmar a instalação

import torch
print(torch.__version__)
# Out:
# 1.13.1+cpu

# %% [markdown]
# ## Imports

# %%
# pytorch mlp for binary classification
import time
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.utils.data import random_split
from torch import Tensor
from torch.nn import Linear
from torch.nn import ReLU
from torch.nn import Sigmoid
from torch.nn import Module
from torch.optim import SGD, Adam
from torch.nn import BCELoss, BCEWithLogitsLoss
from torch.nn.init import kaiming_uniform_
from torch.nn.init import xavier_uniform_

np.random.seed(0) 
torch.manual_seed(0)
import random
random.seed(0)

# %%
#####ir buscar o dataset:
#!wget -c https://raw.githubusercontent.com/jbrownlee/Datasets/master/ionosphere.csv -O ionosphere.csv

# %%
#Constants

#path = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/ionosphere.csv'
PATH = 'ionosphere.csv'
# setting device on GPU if available, else CPU
#device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
##Additional Info when using cuda
#if device.type == 'cuda':
#    print(torch.cuda.get_device_name(0))
#    print('Memory Usage:')
#    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
#    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')


#force cpu
device = torch.device("cpu")
print('Using device:', device)
print()


EPOCHS = 100
BATCH_SIZE = 64
LEARNING_RATE = 0.001
# Out:
# Using device: cpu

# %% [markdown]
# ## *1. Preparar os Dados

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset

# definição classe para o dataset
class CSVDataset(Dataset):
    # ler o dataset
    def __init__(self, path):
        # ler o ficheiro csv para um dataframe
        df = pd.read_csv(path, header=None)
        # separar os inputs e os outputs
        self.X = df.values[:, :-1]
        self.y = df.values[:, -1]
        # garantir que os inputs sejam floats
        self.X = self.X.astype('float32')
        # fazer o encoding dos outputs (label) e garantir que sejam floats
        self.y = LabelEncoder().fit_transform(self.y) #faz o fit e transforma no self.y o 'g' e o 'b' em 0 e 1
        self.y = self.y.astype('float32')
        self.y = self.y.reshape((len(self.y), 1))   
        
    # número de casos no dataset
    def __len__(self):
        return len(self.X)
 
    # retornar um caso
    def __getitem__(self, idx):
        return [self.X[idx], self.y[idx]]
 
    # retornar índices para casos de treino e de teste
    def get_splits(self, n_test=0.33):
        # calcular o tamanho para o split
        test_size = round(n_test * len(self.X))
        train_size = len(self.X) - test_size
        # calcular o split do houldout
        return random_split(self, [train_size, test_size], generator=torch.Generator().manual_seed(42))
    
        # Stratified Sampling for train and test
    def get_splits_strat(self, n_test=0.33):
        train_X, test_X, train_y, test_y = train_test_split(self.X, self.y, 
                                             test_size=n_test,
                                             random_state=999,
                                             shuffle=True,
                                             stratify=self.y)
        train = TensorDataset(torch.from_numpy(train_X),torch.from_numpy(train_y))
        test = TensorDataset(torch.from_numpy(test_X),torch.from_numpy(test_y))
        return train, test
    
# preparar o dataset
def prepare_data(path):
    # criar uma instância do dataset
    dataset = CSVDataset(path)
    # calcular o split
    train, test = dataset.get_splits()
    print('sem strat',type(train))
    # preparar os data loaders
    train_dl = DataLoader(train, batch_size=len(train), shuffle=True) #32 len(train)
    test_dl = DataLoader(test, batch_size=1024, shuffle=False)
    train_dl_all = DataLoader(train, batch_size=len(train), shuffle=False)
    test_dl_all = DataLoader(test, batch_size=len(test), shuffle=False)
    return train_dl, test_dl, train_dl_all, test_dl_all

# preparar o dataset
def prepare_data_strat(path):
    # criar uma instância do dataset
    dataset = CSVDataset(path)
    # calcular o split
    train, test = dataset.get_splits_strat()
    print('com strat',type(train))
    # preparar os data loaders
    train_dl = DataLoader(train, batch_size=len(train), shuffle=True) #32 len(train)
    test_dl = DataLoader(test, batch_size=1024, shuffle=False)
    train_dl_all = DataLoader(train, batch_size=len(train), shuffle=False)
    test_dl_all = DataLoader(test, batch_size=len(test), shuffle=False)
    return train_dl, test_dl, train_dl_all, test_dl_all


# preparar os dados
train_dl, test_dl,  train_dl_all, test_dl_all = prepare_data(PATH)

# sanity check
x,y = next(iter(train_dl))
print(f"Train {x.shape}, {y.shape}")
x,y = next(iter(test_dl))
print(f"Test {x.shape}, {y.shape}")

# preparar os dados
train_s_dl, test_s_dl,  train_s_dl_all, test_s_dl_all = prepare_data_strat(PATH)

# sanity check
x,y = next(iter(train_s_dl))
print(f"Train {x.shape}, {y.shape}")
x,y = next(iter(test_s_dl))
print(f"Test {x.shape}, {y.shape}")
# Out:
# sem strat <class 'torch.utils.data.dataset.Subset'>
# Train torch.Size([235, 34]), torch.Size([235, 1])
# Test torch.Size([116, 34]), torch.Size([116, 1])
# com strat <class 'torch.utils.data.dataset.TensorDataset'>
# Train torch.Size([235, 34]), torch.Size([235, 1])
# Test torch.Size([116, 34]), torch.Size([116, 1])

# %% [markdown]
# ## *1.1 Visualizar os Dados

# %%
from IPython.display import display

def visualize_data(path):
    # criar uma instância do dataset
    df = pd.read_csv(path, header=None)
    display(df)

def visualize_dataset(train_dl, test_dl):
    print(f"Quantidade de casos de Treino:{len(train_dl.dataset)}") 
    print(f"Quantidade de casos de Teste:{len(test_dl.dataset)}")
    x, y = next(iter(train_dl)) #fazer uma iteração nos loaders para ir buscar um batch de casos
    print(f"Shape tensor batch casos treino, input: {x.shape}, output: {y.shape}")
    x, y = next(iter(test_dl))  
    print(f"Shape tensor batch casos teste, input: {x.shape}, output: {y.shape}")

visualize_data(PATH)
visualize_dataset(train_dl, test_dl)
# Out:
#      0   1        2        3        4        5        6        7        8   \
# 0     1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1     1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2     1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3     1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4     1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
# ..   ..  ..      ...      ...      ...      ...      ...      ...      ...
# 346   1   0  0.83508  0.08298  0.73739 -0.14706  0.84349 -0.05567  0.90441
# 347   1   0  0.95113  0.00419  0.95183 -0.02723  0.93438 -0.01920  0.94590
# 348   1   0  0.94701 -0.00034  0.93207 -0.03227  0.95177 -0.03431  0.95584
# 349   1   0  0.90608 -0.01657  0.98122 -0.01989  0.95691 -0.03646  0.85746
# 350   1   0  0.84710  0.13533  0.73638 -0.06151  0.87873  0.08260  0.88928
#
#           9   ...       25       26       27       28       29       30  \
# 0    0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1   -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 2    0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 3    0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 4   -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
# ..       ...  ...      ...      ...      ...      ...      ...      ...
# 346 -0.04622  ... -0.04202  0.83479  0.00123  1.00000  0.12815  0.86660
# 347  0.01606  ...  0.01361  0.93522  0.04925  0.93159  0.08168  0.94066
# 348  0.02446  ...  0.03193  0.92489  0.02542  0.92120  0.02242  0.92459
# 349  0.00110  ... -0.02099  0.89147 -0.07760  0.82983 -0.17238  0.96022
# 350 -0.09139  ... -0.15114  0.81147 -0.04822  0.78207 -0.00703  0.75747
#
#           31       32       33  34
# 0   -0.54487  0.18641 -0.45300   g
# 1   -0.06288 -0.13738 -0.02447   b
# 2   -0.24180  0.56045 -0.38238   g
# 3    1.00000 -0.32382  1.00000   b
# 4   -0.59573 -0.04608 -0.65697   g
# ..       ...      ...      ...  ..
# 346 -0.10714  0.90546 -0.04307   g
# 347 -0.00035  0.91483  0.04712   g
# 348  0.00442  0.92697 -0.00577   g
# 349 -0.03757  0.87403 -0.16243   g
# 350 -0.06678  0.85764 -0.06151   g
#
# [351 rows x 35 columns]
# Quantidade de casos de Treino:235
# Quantidade de casos de Teste:116
# Shape tensor batch casos treino, input: torch.Size([235, 34]), output: torch.Size([235, 1])
# Shape tensor batch casos teste, input: torch.Size([116, 34]), output: torch.Size([116, 1])

# %% [markdown]
# ## *1.2 Verificar balanceamento do dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def visualize_holdout_balance(train_dl, test_dl):
    _, y_train = next(iter(train_dl))                            
    _, y_test = next(iter(test_dl))

    sns.set_style('whitegrid')
    casos_treino=len(y_train) # calcular o nº de casos de treino
    casos_test=len(y_test) # calcular o nº de casos de teste
    b_Train=np.count_nonzero(y_train == 0) # calcular o nº de 0 nos casos de treino
    g_Train = np.count_nonzero(y_train == 1) # calcular o nº de 1 nos casos de treino
    b_Test=np.count_nonzero(y_test == 0) # calcular o nº de 0 nos casos de teste
    g_Test = np.count_nonzero(y_test == 1) # calcular o nº de 1 nos casos de teste
    print("casos_treino:",casos_treino)
    print("g_Train: ", g_Train)
    print("b_Train: ", b_Train)
    print("g_Train/b_Train: ", g_Train/b_Train) # rácio de g em b
    print("casos_test:",casos_test)
    print("g_Test: ", g_Test)
    print("b_Test: ", b_Test)
    print("g_Test/b_Test: ", g_Test/b_Test) # rácio de g em b

    grafico=sns.barplot(x=['g_Train','b_Train', 'g_Test', 'b_Test'], 
                        y=[g_Train,b_Train, g_Test, b_Test])
    grafico.set_title('Data balance ')
    plt.xticks(rotation=70)
    plt.tight_layout()
    plt.show() 
    
visualize_holdout_balance(train_dl_all, test_dl_all)
# Out:
# casos_treino: 235
# g_Train:  156
# b_Train:  79
# g_Train/b_Train:  1.9746835443037976
# casos_test: 116
# g_Test:  69
# b_Test:  47
# g_Test/b_Test:  1.4680851063829787

# %%
visualize_holdout_balance(train_s_dl_all, test_s_dl_all)
# Out:
# casos_treino: 235
# g_Train:  151
# b_Train:  84
# g_Train/b_Train:  1.7976190476190477
# casos_test: 116
# g_Test:  74
# b_Test:  42
# g_Test/b_Test:  1.7619047619047619

# %% [markdown]
# ## *2. Definir o Modelo

# %%
#### Instalar o torchinfo
#!pip install torchinfo

# %%
from torchinfo import summary

# Definição da classe para o modelo
class MLP(Module):
    # definir elementos do modelo
    def __init__(self, n_inputs):
        super(MLP, self).__init__()
        # input para a primeira camada - Linear - ReLU
        self.hidden1 = Linear(n_inputs, 20)
        kaiming_uniform_(self.hidden1.weight, nonlinearity='relu') # He initialization
        self.act1 = ReLU()
        # segunda camada - Linear - ReLU
        self.hidden2 = Linear(20, 10)
        kaiming_uniform_(self.hidden2.weight, nonlinearity='relu')
        self.act2 = ReLU()
        self.hidden3 = Linear(10, 8)
        kaiming_uniform_(self.hidden3.weight, nonlinearity='relu')
        self.act3 = ReLU()
        # terceira camada e output Linear - Sigmoid
        self.hidden4 = Linear(8, 1)
        xavier_uniform_(self.hidden4.weight) # Glorot initialization
        self.act4 = Sigmoid()
 
    # sequência de propagação do input 
    def forward(self, X):
        # input para a primeira camada
        X = self.hidden1(X)
        X = self.act1(X)
        # input para a segunda camada
        X = self.hidden2(X)
        X = self.act2(X)
        # input para a terceira camada e output
        X = self.hidden3(X)
        X = self.act3(X)
        X = self.hidden4(X)
        X = self.act4(X)
        return X
 
# definir a rede neuronal
model1 = MLP(34)
model2 = MLP(34)
# visualizar a rede
batch_size = 32
# sumário da rede
print(summary(model1, input_size=(batch_size, 34), device=device, verbose=0)) #verbose=2 Show weight and bias layers in full detail
model1.to(device)
model2.to(device)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLP                                      [32, 1]                   --
# ├─Linear: 1-1                            [32, 20]                  700
# ├─ReLU: 1-2                              [32, 20]                  --
# ├─Linear: 1-3                            [32, 10]                  210
# ├─ReLU: 1-4                              [32, 10]                  --
# ├─Linear: 1-5                            [32, 8]                   88
# ├─ReLU: 1-6                              [32, 8]                   --
# ├─Linear: 1-7                            [32, 1]                   9
# ├─Sigmoid: 1-8                           [32, 1]                   --
# ==========================================================================================
# Total params: 1,007
# Trainable params: 1,007
# Non-trainable params: 0
# Total mult-adds (M): 0.03
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.02
# ==========================================================================================
# MLP(
#   (hidden1): Linear(in_features=34, out_features=20, bias=True)
#   (act1): ReLU()
#   (hidden2): Linear(in_features=20, out_features=10, bias=True)
#   (act2): ReLU()
#   (hidden3): Linear(in_features=10, out_features=8, bias=True)
#   (act3): ReLU()
#   (hidden4): Linear(in_features=8, out_features=1, bias=True)
#   (act4): Sigmoid()
# )

# %% [markdown]
# ## *3. Treinar o Modelo

# %%
## Instalar o livelossplot
#!pip install livelossplot

# %%
#versão com display de gráfico
from livelossplot import PlotLosses

# treino do modelo
def train_model(train_dl, model):
    liveloss = PlotLosses() # para visualizarmos o processo de treino
    # definir a função de loss e a função de otimização
    # criterion = BCELoss() # Binary Cross Entropy - precisa de signoid como função de ativação na saida
    criterion = BCEWithLogitsLoss()
    #optimizer = SGD(model.parameters(), lr=LEARNING_RATE, momentum=0.9) # stochastic gradient descent
    optimizer = Adam(model.parameters(), lr=LEARNING_RATE)
    # iterar as epochs
    for epoch in range(EPOCHS):
        logs = {} # para visualizarmos o processo de treino
        # iterar as batchs
        epoch_loss  = 0.0 # para visualizarmos o processo de treino
        epoch_acc  = 0.0 # para visualizarmos o processo de treino
        for i, (inputs, labels) in enumerate(train_dl): # backpropagation
            # inicializar os gradientes
            optimizer.zero_grad() # coloca os gradientes de todos os parametros a zero
            # calcular o output do modelo - previsao/forward
            outputs = model(inputs)
            # calcular o loss
            loss = criterion(outputs, labels)
            # calcular a accuracy
            #acc = binary_acc(outputs, labels)
            acc = accuracy_score(outputs.detach().numpy().round(), labels.numpy(), normalize=False)
            # atribuição alteraçoes "In the backward pass we receive a Tensor containing the gradient of the loss
            # with respect to the output, and we need to compute the gradient of the loss with respect to the input.
            loss.backward() #backpropagation
            # update pesos do modelo
            optimizer.step()
            # calcular epochs de loss e epochs de accuracy
            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
        epoch_loss = epoch_loss/len(train_dl.dataset)
        epoch_acc = epoch_acc/len(train_dl.dataset)
        print(f'Epoch {epoch:03}: | Loss: {epoch_loss:.5f} | Acc: {epoch_acc:.3f}')      
        logs['loss'] = epoch_loss # para visualizarmos o processo de treino
        logs['accuracy'] = epoch_acc # para visualizarmos o processo de treino
        liveloss.update(logs) # para visualizarmos o processo de treino
        liveloss.send() # para visualizarmos o processo de treino
 
# treinar o modelo
#%timeit train_model(train_dl, model1)

# %%
#%%timeit
# treinar o modelo

it = time.time()
train_model(train_dl, model1)
delta_t= time.time() - it
print(f'Execution time: {delta_t:.3} seconds')
# Out:
# accuracy
# 	accuracy         	 (min:    0.366, max:    0.940, cur:    0.940)
# Loss
# 	loss             	 (min:    0.002, max:    0.003, cur:    0.002)
# Execution time: 31.0 seconds

# %%
#%%timeit
train_model(train_s_dl, model2)
# Out:
# accuracy
# 	accuracy         	 (min:    0.357, max:    0.881, cur:    0.881)
# Loss
# 	loss             	 (min:    0.002, max:    0.003, cur:    0.002)

# %% [markdown]
# ## *4. Avaliar o Modelo

# %%
# Avaliar o modelo
def evaluate_model(test_dl, model):
    predictions = list()
    predictions_prob = list()
    actual_values = list()
    for i, (inputs, labels) in enumerate(test_dl):
        # avaliar o modelo com os casos de teste
        yprev = model(inputs)
        # retirar o array numpy
        yprev = yprev.detach().numpy()
        actual = labels.numpy()
        # arredondar para obter a classe
        predictions_prob.append(yprev) #vamos guardar tambem a probabilidade
        yprev = yprev.round()
        # guardar
        predictions.append(yprev)
        actual_values.append(actual)
    predictions_prob = np.vstack(predictions_prob)
    predictions = np.vstack(predictions)
    actual_values =  np.vstack(actual_values)
    return predictions_prob, predictions, actual_values
 
def display_confusion_matrix(cm):
    plt.figure(figsize = (16,8))
    sns.heatmap(cm,annot=True,xticklabels=['b','g'],yticklabels=['b','g'], annot_kws={"size": 12}, fmt='g', linewidths=.5)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
# avaliar o modelo
predictions_prob, predictions, actual_values = evaluate_model(test_dl, model1)
#actuals, predictions = evaluate_model(train_dl, model)
# calcular a accuracy
acc = accuracy_score(actual_values, predictions)
print(f'Accuracy: {acc:0.3f}\n')

acertou=0
falhou = 0
for prob, r,p in zip(predictions_prob, actual_values, predictions):
    print(f'real:{r} probabilidade:{prob} previsão:{p}') 
    if r==p: acertou+=1  
    else: falhou+=1
print(f'acertou:{acertou} falhou:{falhou}')

# relatório de classificação: precision, recall, f1-score, support vs. 0,1, accuracy, macro avg, weighted avg
print(classification_report(actual_values, predictions))

# matriz confusão
cm = confusion_matrix(actual_values, predictions)
print (cm)
display_confusion_matrix(cm)
# Out:
# Accuracy: 0.888
#
# real:[1.] probabilidade:[0.6310573] previsão:[1.]
# real:[0.] probabilidade:[0.33065525] previsão:[0.]
# real:[1.] probabilidade:[0.72212195] previsão:[1.]
# real:[0.] probabilidade:[0.55215544] previsão:[1.]
# real:[0.] probabilidade:[0.26860604] previsão:[0.]
# real:[1.] probabilidade:[0.6108988] previsão:[1.]
# real:[0.] probabilidade:[0.2219463] previsão:[0.]
# real:[1.] probabilidade:[0.59099907] previsão:[1.]
# real:[1.] probabilidade:[0.69302356] previsão:[1.]
# real:[1.] probabilidade:[0.63566667] previsão:[1.]
# real:[1.] probabilidade:[0.6602333] previsão:[1.]
# real:[1.] probabilidade:[0.72741616] previsão:[1.]
# real:[1.] probabilidade:[0.64831764] previsão:[1.]
# real:[0.] probabilidade:[0.12587298] previsão:[0.]
# real:[0.] probabilidade:[0.11396001] previsão:[0.]
# real:[0.] probabilidade:[0.03312174] previsão:[0.]
# real:[1.] probabilidade:[0.7395941] previsão:[1.]
# real:[1.] probabilidade:[0.7398211] previsão:[1.]
# real:[0.] probabilidade:[0.07528073] previsão:[0.]
# real:[0.] probabilidade:[0.16703703] previsão:[0.]
# real:[0.] probabilidade:[0.06842975] previsão:[0.]
# real:[1.] probabilidade:[0.5928655] previsão:[1.]
# real:[0.] probabilidade:[0.05466043] previsão:[0.]
# real:[0.] probabilidade:[0.50439984] previsão:[1.]
# real:[0.] probabilidade:[0.2388222] previsão:[0.]
# real:[1.] probabilidade:[0.7127808] previsão:[1.]
# real:[1.] probabilidade:[0.6480393] previsão:[1.]
# real:[0.] probabilidade:[0.70683384] previsão:[1.]
# real:[1.] probabilidade:[0.6029837] previsão:[1.]
# real:[0.] probabilidade:[0.6887272] previsão:[1.]
# real:[1.] probabilidade:[0.7459162] previsão:[1.]
# real:[1.] probabilidade:[0.62160885] previsão:[1.]
# real:[1.] probabilidade:[0.56022024] previsão:[1.]
# real:[0.] probabilidade:[0.03049516] previsão:[0.]
# real:[0.] probabilidade:[0.58934015] previsão:[1.]
# real:[0.] probabilidade:[0.12154333] previsão:[0.]
# real:[1.] probabilidade:[0.74979746] previsão:[1.]
# real:[0.] probabilidade:[0.01584843] previsão:[0.]
# real:[1.] probabilidade:[0.73536533] previsão:[1.]
# real:[1.] probabilidade:[0.68604046] previsão:[1.]
# real:[1.] probabilidade:[0.72215265] previsão:[1.]
# real:[1.] probabilidade:[0.69888043] previsão:[1.]
# real:[0.] probabilidade:[0.3305443] previsão:[0.]
# real:[0.] probabilidade:[0.33451325] previsão:[0.]
# real:[1.] probabilidade:[0.5164811] previsão:[1.]
# real:[0.] probabilidade:[0.33144206] previsão:[0.]
# real:[0.] probabilidade:[0.13166343] previsão:[0.]
# real:[1.] probabilidade:[0.606558] previsão:[1.]
# real:[0.] probabilidade:[0.23930208] previsão:[0.]
# real:[1.] probabilidade:[0.74013233] previsão:[1.]
# real:[1.] probabilidade:[0.74020237] previsão:[1.]
# real:[1.] probabilidade:[0.22052386] previsão:[0.]
# real:[1.] probabilidade:[0.6721268] previsão:[1.]
# real:[1.] probabilidade:[0.7456988] previsão:[1.]
# real:[1.] probabilidade:[0.6939829] previsão:[1.]
# real:[1.] probabilidade:[0.6633999] previsão:[1.]
# real:[1.] probabilidade:[0.6179203] previsão:[1.]
# real:[0.] probabilidade:[0.25272965] previsão:[0.]
# real:[0.] probabilidade:[0.11952788] previsão:[0.]
# real:[1.] probabilidade:[0.74554867] previsão:[1.]
# real:[1.] probabilidade:[0.75330377] previsão:[1.]
# real:[1.] probabilidade:[0.70251286] previsão:[1.]
# real:[0.] probabilidade:[0.3679309] previsão:[0.]
# real:[1.] probabilidade:[0.65235627] previsão:[1.]
# real:[0.] probabilidade:[0.15719485] previsão:[0.]
# real:[0.] probabilidade:[0.02131147] previsão:[0.]
# real:[1.] probabilidade:[0.7424165] previsão:[1.]
# real:[1.] probabilidade:[0.70000416] previsão:[1.]
# real:[0.] probabilidade:[0.09149651] previsão:[0.]
# real:[1.] probabilidade:[0.71267456] previsão:[1.]
# real:[1.] probabilidade:[0.7239628] previsão:[1.]
# real:[0.] probabilidade:[0.66476655] previsão:[1.]
# real:[1.] probabilidade:[0.4798371] previsão:[0.]
# real:[1.] probabilidade:[0.7277796] previsão:[1.]
# real:[1.] probabilidade:[0.68125635] previsão:[1.]
# real:[0.] probabilidade:[0.07766493] previsão:[0.]
# real:[1.] probabilidade:[0.7057451] previsão:[1.]
# real:[1.] probabilidade:[0.62488663] previsão:[1.]
# real:[0.] probabilidade:[0.16711253] previsão:[0.]
# real:[0.] probabilidade:[0.43501678] previsão:[0.]
# real:[0.] probabilidade:[0.49744388] previsão:[0.]
# real:[0.] probabilidade:[0.36863825] previsão:[0.]
# real:[1.] probabilidade:[0.74528235] previsão:[1.]
# real:[1.] probabilidade:[0.6568981] previsão:[1.]
# real:[1.] probabilidade:[0.62184095] previsão:[1.]
# real:[1.] probabilidade:[0.64014] previsão:[1.]
# real:[1.] probabilidade:[0.72409815] previsão:[1.]
# real:[1.] probabilidade:[0.7104674] previsão:[1.]
# real:[1.] probabilidade:[0.6596204] previsão:[1.]
# real:[0.] probabilidade:[0.33518896] previsão:[0.]
# real:[0.] probabilidade:[0.19167054] previsão:[0.]
# real:[1.] probabilidade:[0.7458426] previsão:[1.]
# real:[1.] probabilidade:[0.73487] previsão:[1.]
# real:[1.] probabilidade:[0.59776384] previsão:[1.]
# real:[1.] probabilidade:[0.7428801] previsão:[1.]
# real:[1.] probabilidade:[0.675773] previsão:[1.]
# real:[1.] probabilidade:[0.695895] previsão:[1.]
# real:[1.] probabilidade:[0.42458245] previsão:[0.]
# real:[0.] probabilidade:[0.45054978] previsão:[0.]
# real:[1.] probabilidade:[0.62248975] previsão:[1.]
# real:[0.] probabilidade:[0.37036243] previsão:[0.]
# real:[0.] probabilidade:[0.23410042] previsão:[0.]
# real:[1.] probabilidade:[0.63826543] previsão:[1.]
# real:[1.] probabilidade:[0.7104731] previsão:[1.]
# real:[0.] probabilidade:[0.29306066] previsão:[0.]
# real:[0.] probabilidade:[0.45985] previsão:[0.]
# real:[0.] probabilidade:[0.37597525] previsão:[0.]
# real:[1.] probabilidade:[0.19221196] previsão:[0.]
# real:[1.] probabilidade:[0.4576765] previsão:[0.]
# real:[0.] probabilidade:[0.6723114] previsão:[1.]
# real:[1.] probabilidade:[0.69337296] previsão:[1.]
# real:[1.] probabilidade:[0.56168365] previsão:[1.]
# real:[0.] probabilidade:[0.08008844] previsão:[0.]
# real:[1.] probabilidade:[0.6635152] previsão:[1.]
# real:[0.] probabilidade:[0.00185415] previsão:[0.]
# real:[1.] probabilidade:[0.4146295] previsão:[0.]
# acertou:103 falhou:13
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.85      0.86        47
#          1.0       0.90      0.91      0.91        69
#
#     accuracy                           0.89       116
#    macro avg       0.88      0.88      0.88       116
# weighted avg       0.89      0.89      0.89       116
#
# [[40  7]
#  [ 6 63]]

# %%
# avaliar o modelo
predictions_prob, predictions, actual_values = evaluate_model(test_s_dl, model2)
#actuals, predictions = evaluate_model(train_dl, model)
# calcular a accuracy
acc = accuracy_score(actual_values, predictions)
print(f'Accuracy: {acc:0.3f}\n')

acertou=0
falhou = 0
for prob, r,p in zip(predictions_prob, actual_values, predictions):
    print(f'real:{r} probabilidade:{prob} previsão:{p}') 
    if r==p: acertou+=1  
    else: falhou+=1
print(f'acertou:{acertou} falhou:{falhou}')

# relatório de classificação: precision, recall, f1-score, support vs. 0,1, accuracy, macro avg, weighted avg
print(classification_report(actual_values, predictions))

# matriz confusão
cm = confusion_matrix(actual_values, predictions)
print (cm)
display_confusion_matrix(cm)
# Out:
# Accuracy: 0.862
#
# real:[1.] probabilidade:[0.6685715] previsão:[1.]
# real:[0.] probabilidade:[0.27038115] previsão:[0.]
# real:[0.] probabilidade:[0.13183257] previsão:[0.]
# real:[1.] probabilidade:[0.6615837] previsão:[1.]
# real:[1.] probabilidade:[0.6300814] previsão:[1.]
# real:[1.] probabilidade:[0.6398105] previsão:[1.]
# real:[1.] probabilidade:[0.61170846] previsão:[1.]
# real:[1.] probabilidade:[0.6415677] previsão:[1.]
# real:[1.] probabilidade:[0.6628564] previsão:[1.]
# real:[1.] probabilidade:[0.6851894] previsão:[1.]
# real:[0.] probabilidade:[0.1345301] previsão:[0.]
# real:[0.] probabilidade:[0.34137097] previsão:[0.]
# real:[1.] probabilidade:[0.5710682] previsão:[1.]
# real:[1.] probabilidade:[0.4963341] previsão:[0.]
# real:[1.] probabilidade:[0.56506866] previsão:[1.]
# real:[0.] probabilidade:[0.15974092] previsão:[0.]
# real:[1.] probabilidade:[0.6244424] previsão:[1.]
# real:[1.] probabilidade:[0.6413612] previsão:[1.]
# real:[1.] probabilidade:[0.5516898] previsão:[1.]
# real:[0.] probabilidade:[0.5984427] previsão:[1.]
# real:[1.] probabilidade:[0.18570238] previsão:[0.]
# real:[0.] probabilidade:[0.23459485] previsão:[0.]
# real:[1.] probabilidade:[0.6859128] previsão:[1.]
# real:[1.] probabilidade:[0.6834968] previsão:[1.]
# real:[1.] probabilidade:[0.64946157] previsão:[1.]
# real:[1.] probabilidade:[0.6256905] previsão:[1.]
# real:[0.] probabilidade:[0.28997704] previsão:[0.]
# real:[1.] probabilidade:[0.5920604] previsão:[1.]
# real:[0.] probabilidade:[0.00502681] previsão:[0.]
# real:[1.] probabilidade:[0.54784113] previsão:[1.]
# real:[1.] probabilidade:[0.5629064] previsão:[1.]
# real:[0.] probabilidade:[0.30379584] previsão:[0.]
# real:[0.] probabilidade:[0.1706523] previsão:[0.]
# real:[1.] probabilidade:[0.6437385] previsão:[1.]
# real:[1.] probabilidade:[0.61899203] previsão:[1.]
# real:[1.] probabilidade:[0.52416635] previsão:[1.]
# real:[1.] probabilidade:[0.649051] previsão:[1.]
# real:[0.] probabilidade:[0.4396116] previsão:[0.]
# real:[1.] probabilidade:[0.3927921] previsão:[0.]
# real:[0.] probabilidade:[0.1047008] previsão:[0.]
# real:[1.] probabilidade:[0.52309364] previsão:[1.]
# real:[0.] probabilidade:[0.13183257] previsão:[0.]
# real:[1.] probabilidade:[0.6738206] previsão:[1.]
# real:[1.] probabilidade:[0.6405386] previsão:[1.]
# real:[1.] probabilidade:[0.65328836] previsão:[1.]
# real:[1.] probabilidade:[0.69137615] previsão:[1.]
# real:[1.] probabilidade:[0.6384293] previsão:[1.]
# real:[1.] probabilidade:[0.67538357] previsão:[1.]
# real:[1.] probabilidade:[0.41201895] previsão:[0.]
# real:[1.] probabilidade:[0.6584492] previsão:[1.]
# real:[1.] probabilidade:[0.35731992] previsão:[0.]
# real:[0.] probabilidade:[0.6736824] previsão:[1.]
# real:[1.] probabilidade:[0.6616454] previsão:[1.]
# real:[1.] probabilidade:[0.605885] previsão:[1.]
# real:[1.] probabilidade:[0.63383144] previsão:[1.]
# real:[0.] probabilidade:[0.43632078] previsão:[0.]
# real:[1.] probabilidade:[0.62686485] previsão:[1.]
# real:[1.] probabilidade:[0.64425844] previsão:[1.]
# real:[1.] probabilidade:[0.7029098] previsão:[1.]
# real:[0.] probabilidade:[0.17426024] previsão:[0.]
# real:[0.] probabilidade:[0.03348801] previsão:[0.]
# real:[1.] probabilidade:[0.57706743] previsão:[1.]
# real:[0.] probabilidade:[0.5119402] previsão:[1.]
# real:[1.] probabilidade:[0.3010946] previsão:[0.]
# real:[1.] probabilidade:[0.6091877] previsão:[1.]
# real:[1.] probabilidade:[0.66000354] previsão:[1.]
# real:[1.] probabilidade:[0.5024781] previsão:[1.]
# real:[1.] probabilidade:[0.658748] previsão:[1.]
# real:[1.] probabilidade:[0.6398384] previsão:[1.]
# real:[0.] probabilidade:[0.6956418] previsão:[1.]
# real:[0.] probabilidade:[0.13857356] previsão:[0.]
# real:[1.] probabilidade:[0.6590999] previsão:[1.]
# real:[0.] probabilidade:[0.4863423] previsão:[0.]
# real:[0.] probabilidade:[0.29857686] previsão:[0.]
# real:[0.] probabilidade:[0.617723] previsão:[1.]
# real:[0.] probabilidade:[0.24505302] previsão:[0.]
# real:[0.] probabilidade:[0.04892464] previsão:[0.]
# real:[1.] probabilidade:[0.44358173] previsão:[0.]
# real:[0.] probabilidade:[0.08653479] previsão:[0.]
# real:[0.] probabilidade:[0.48674917] previsão:[0.]
# real:[0.] probabilidade:[0.18514915] previsão:[0.]
# real:[1.] probabilidade:[0.548982] previsão:[1.]
# real:[0.] probabilidade:[0.07129305] previsão:[0.]
# real:[0.] probabilidade:[0.03422292] previsão:[0.]
# real:[1.] probabilidade:[0.67150724] previsão:[1.]
# real:[1.] probabilidade:[0.6697715] previsão:[1.]
# real:[0.] probabilidade:[0.33968967] previsão:[0.]
# real:[1.] probabilidade:[0.52386695] previsão:[1.]
# real:[1.] probabilidade:[0.68237776] previsão:[1.]
# real:[0.] probabilidade:[0.01936836] previsão:[0.]
# real:[0.] probabilidade:[0.27688092] previsão:[0.]
# real:[1.] probabilidade:[0.6747256] previsão:[1.]
# real:[0.] probabilidade:[0.15546755] previsão:[0.]
# real:[0.] probabilidade:[0.17620221] previsão:[0.]
# real:[0.] probabilidade:[0.01808356] previsão:[0.]
# real:[1.] probabilidade:[0.66475964] previsão:[1.]
# real:[1.] probabilidade:[0.5717259] previsão:[1.]
# real:[1.] probabilidade:[0.54762685] previsão:[1.]
# real:[1.] probabilidade:[0.69343024] previsão:[1.]
# real:[0.] probabilidade:[0.12895453] previsão:[0.]
# real:[1.] probabilidade:[0.5673295] previsão:[1.]
# real:[0.] probabilidade:[0.5919409] previsão:[1.]
# real:[1.] probabilidade:[0.57185125] previsão:[1.]
# real:[0.] probabilidade:[0.34774324] previsão:[0.]
# real:[1.] probabilidade:[0.43946606] previsão:[0.]
# real:[1.] probabilidade:[0.46857083] previsão:[0.]
# real:[0.] probabilidade:[0.00559345] previsão:[0.]
# real:[1.] probabilidade:[0.57465625] previsão:[1.]
# real:[1.] probabilidade:[0.6760306] previsão:[1.]
# real:[1.] probabilidade:[0.6840076] previsão:[1.]
# real:[0.] probabilidade:[0.2592915] previsão:[0.]
# real:[1.] probabilidade:[0.69546336] previsão:[1.]
# real:[1.] probabilidade:[0.28794387] previsão:[0.]
# real:[1.] probabilidade:[0.65336114] previsão:[1.]
# real:[1.] probabilidade:[0.55356586] previsão:[1.]
# real:[1.] probabilidade:[0.6396243] previsão:[1.]
# acertou:100 falhou:16
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.86      0.82        42
#          1.0       0.91      0.86      0.89        74
#
#     accuracy                           0.86       116
#    macro avg       0.85      0.86      0.85       116
# weighted avg       0.87      0.86      0.86       116
#
# [[36  6]
#  [10 64]]

# %% [markdown]
# ## *5. Usar o Modelo

# %%
# fazer uma previsão utilizando um caso
def predict(row, model):
    # converter row para tensor
    row = Tensor([row])
    # fazer a previsão
    yprev = model(row)
    # retirar o array numpy
    yprev = yprev.detach().numpy()
    return yprev
 
# fazer uma única previsão (classe esperada = 1)
row = [1,0,0.99539,-0.05889,0.85243,0.02306,0.83398,-0.37708,1,0.03760,0.85243,-0.17755,0.59755,-0.44945,0.60536,-0.38223,0.84356,-0.38542,0.58212,-0.32192,0.56971,-0.29674,0.36946,-0.47357,0.56811,-0.51171,0.41078,-0.46168,0.21266,-0.34090,0.42267,-0.54487,0.18641,-0.45300]
yprev = predict(row, model1)
print('Predicted: %.3f (class=%d)' % (yprev, yprev.round()))
yprev = predict(row, model2)
print('Predicted: %.3f (class=%d)' % (yprev, yprev.round()))
# Out:
# Predicted: 0.680 (class=1)
# Predicted: 0.575 (class=1)
